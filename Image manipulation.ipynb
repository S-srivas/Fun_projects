# %%
import numpy as np
from PIL import Image
from matplotlib import image
from matplotlib import pyplot
from numpy import asarray

# %%
image = Image.open('flower.png')
# summarize some details about the image
print(image.format)
print(image.size)
print(image.mode)
# Out:
# PNG
# (513, 340)
# RGBA

# %%
image = image.imread('flower.png')
# summarize shape of the pixel array
print(image.dtype)
print(image.shape)
# display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()
# Out:
# float32
# (340, 513, 4)

# %%
data = asarray(image)
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
print (data)
# Out:
# <module 'matplotlib.image' from '/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py'>

# %%
im = np.array(Image.open('flower.png').convert('L')) #you can pass multiple arguments in single line
print(type(im))

gr_im= Image.fromarray(im).save('gray toy.png')
# Out:
# <class 'numpy.ndarray'>
